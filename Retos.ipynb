# %% [markdown]
# <a href="https://colab.research.google.com/github/HelenDiMo/Estudiando_Python/blob/main/Retos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ejemplo práctico: "El castigo de Bart Simpson"

for i in range(10):
  print("No volveré a tirar aviones de papel en clase.")
# Out:
# No volveré a tirar aviones de papel en clase.
# No volveré a tirar aviones de papel en clase.
# No volveré a tirar aviones de papel en clase.
# No volveré a tirar aviones de papel en clase.
# No volveré a tirar aviones de papel en clase.
# No volveré a tirar aviones de papel en clase.
# No volveré a tirar aviones de papel en clase.
# No volveré a tirar aviones de papel en clase.
# No volveré a tirar aviones de papel en clase.
# No volveré a tirar aviones de papel en clase.

# %%
#¿Te imaginas para qué podrías usar ese número dentro de un bucle? Por ejemplo, para decir: "Hamburguesa número 1", "Hamburguesa número 2"... ¿Te atreverías a intentar imprimir eso usando la i?

for i in range(10):
  print(f"Este es el cactus número {i+1}")
# Out:
# Este es el cactus número 1
# Este es el cactus número 2
# Este es el cactus número 3
# Este es el cactus número 4
# Este es el cactus número 5
# Este es el cactus número 6
# Este es el cactus número 7
# Este es el cactus número 8
# Este es el cactus número 9
# Este es el cactus número 10
