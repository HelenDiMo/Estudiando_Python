# %% [markdown]
# <a href="https://colab.research.google.com/github/HelenDiMo/Estudiando_Python/blob/main/Estudiando_Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Escribir un programa que muestre por pantalla la frase ¡Hola
# mundo!
#
# print() es una función que muestra texto en pantalla.
# Los textos van entre comillas.

# %%
print("¡Hola Mundo!")
# Out:
# ¡Hola Mundo!

# %% [markdown]
# Modiﬁca el mensaje de salida para que diga:
#
# 🚀 "Hola, me llamo [su nombre] y estoy aprendiendo Python"

# %%
nombre = "Helena"
print(f"Hola, me llamo {nombre} y estoy aprendiendo Python")
# Out:
# Hola, me llamo Helena y estoy aprendiendo Python
